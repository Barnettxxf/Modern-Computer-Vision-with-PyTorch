# %% [markdown]
# <a href="https://colab.research.google.com/github/Barnettxxf/Modern-Computer-Vision-with-PyTorch/blob/master/Chapter06/Class_activation_maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
#files.upload()
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle
#!kaggle datasets download iarunava/cell-images-for-detecting-malaria
# !unzip cell-images-for-detecting-malaria.zip
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/iarunava/cell-images-for-detecting-malaria
# License(s): unknown
# User cancelled operation
# Archive:  cell-images-for-detecting-malaria.zip
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_162.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_163.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_164.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_165.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_166.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_167.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_168.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_169.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_170.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_171.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144348_cell_138.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144348_cell_139.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144348_cell_140.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144348_cell_141.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144348_cell_142.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144348_cell_143.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144348_cell_144.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144823_cell_157.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144823_cell_158.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144823_cell_159.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144823_cell_160.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144823_cell_161.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_144823_cell_162.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_145042_cell_162.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_145042_cell_163.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_145042_cell_164.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_145042_cell_165.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_145042_cell_166.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_145042_cell_167.png
#   inflating: cell_images/Parasitized/C100P61ThinF_IMG_20150918_145422_cell_163.png
#   inflating: cell_images/Parasitized/C102P63ThinF_IMG_20150918_162927_cell_2.png
#   inflating: cell_images/Parasitized/C102P63ThinF_IMG_20150918_162927_cell_3.png
#   inflating: cell_images/Parasitized/C102P63ThinF_IMG_20150918_162927_cell_4.png
#   inflating: cell_images/Parasitized/C102P63ThinF_IMG_20150918_162927_cell_5.png
#   inflating: cell_images/Parasitized/C102P63ThinF_IMG_20150918_163054_cell_167.png
#   inflating: cell_images/Parasitized/C102P63ThinF_IMG_20150918_163054_cell_168.png
#   inflating: cell_images/Parasitized/C102P63ThinF_IMG_20150918_163054_cell_169.png
#   inflating: cell_images/Parasitized/C102P63ThinF_IMG_20150918_163054_cell_170.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164250_cell_170.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164250_cell_171.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164250_cell_172.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164250_cell_173.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164250_cell_174.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164250_cell_175.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164331_cell_184.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164331_cell_185.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164331_cell_186.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164331_cell_187.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164553_cell_167.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164553_cell_168.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164553_cell_169.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164553_cell_170.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164553_cell_171.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164553_cell_172.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_164553_cell_173.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_165016_cell_158.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_165016_cell_159.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_165016_cell_160.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_165016_cell_161.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_165016_cell_162.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_165125_cell_163.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_165125_cell_164.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_165125_cell_165.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_165125_cell_166.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_165510_cell_176.png
#   inflating: cell_images/Parasitized/C103P64ThinF_IMG_20150918_165510_cell_177.png
png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123608_cell_146.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123608_cell_147.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123608_cell_148.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123608_cell_149.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123608_cell_150.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123608_cell_151.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123608_cell_152.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123608_cell_153.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123608_cell_154.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_126.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_127.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_128.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_129.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_130.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_131.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_132.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_133.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_134.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_135.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_136.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_137.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_138.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_139.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_140.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_141.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_142.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_143.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_144.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124304_cell_161.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124304_cell_162.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124304_cell_163.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124304_cell_164.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124304_cell_165.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124304_cell_166.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124304_cell_167.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124304_cell_168.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124304_cell_169.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124304_cell_170.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124304_cell_171.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124304_cell_172.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124304_cell_173.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_142.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_143.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_144.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_145.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_146.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_147.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_148.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_149.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_150.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_151.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_152.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_153.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_154.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_155.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_156.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_157.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_158.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_159.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_160.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_161.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_162.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_163.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_164.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_165.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124345_cell_166.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124425_cell_132.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124425_cell_133.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124425_cell_134.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124425_cell_135.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124425_cell_136.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124425_cell_137.png
#   inflating: cell_images/Parasitized/C119P80ThinF_IMG_20151002_124425_cell_138.png

# %%
import os
if not os.path.exists('cell_images'):
    # !pip install -U -q torch_snippets
    # !wget -q ftp://lhcftp.nlm.nih.gov/Open-Access-Datasets/Malaria/cell_images.zip
    # !unzip -qq cell_images.zip
    # !rm cell_images.zip
from torch_snippets import *
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 36.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.0/221.0 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 91.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 77.7 MB/s eta 0:00:00
#   Building wheel for typing (setup.py) ... done
# unzip:  cannot find or open cell_images.zip, cell_images.zip.zip or cell_images.zip.ZIP.
# rm: cannot remove 'cell_images.zip': No such file or directory

# %%
id2int = {'Parasitized': 0, 'Uninfected': 1}

# %%
from torchvision import transforms as T

trn_tfms = T.Compose([
    T.ToPILImage(),
    T.Resize(128),
    T.CenterCrop(128),
    T.ColorJitter(brightness=(0.95,1.05),
                  contrast=(0.95,1.05),
                  saturation=(0.95,1.05),
                  hue=0.05),
    T.RandomAffine(5, translate=(0.01,0.1)),
    T.ToTensor(),
    T.Normalize(mean=[0.5, 0.5, 0.5],
                std=[0.5, 0.5, 0.5]),
])

# %%
val_tfms = T.Compose([
    T.ToPILImage(),
    T.Resize(128),
    T.CenterCrop(128),
    T.ToTensor(),
    T.Normalize(mean=[0.5, 0.5, 0.5],
                std=[0.5, 0.5, 0.5]),
])

# %%
from torch.utils.data import Dataset
class MalariaImages(Dataset):

    def __init__(self, files, transform=None):
        self.files = files
        self.transform = transform
        logger.info(len(self))

    def __len__(self):
        return len(self.files)

    def __getitem__(self, ix):
        fpath = self.files[ix]
        clss = fname(parent(fpath))
        img = read(fpath, 1)
        return img, clss

    def choose(self):
        return self[randint(len(self))]

    def collate_fn(self, batch):
        _imgs, classes = list(zip(*batch))
        if self.transform:
            imgs = [self.transform(img)[None] for img in _imgs]
        classes = [torch.tensor([id2int[clss]]) for clss in classes]
        imgs, classes = [torch.cat(i).to(device) for i in [imgs, classes]]
        return imgs, classes, _imgs

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

device = 'cuda' if torch.cuda.is_available() else 'cpu'
all_files = Glob('cell_images/*/*.png')
np.random.seed(10)
np.random.shuffle(all_files)

from sklearn.model_selection import train_test_split
trn_files, val_files = train_test_split(all_files, random_state=1, test_size=0.2)

trn_ds = MalariaImages(trn_files, transform=trn_tfms)
val_ds = MalariaImages(val_files, transform=val_tfms)
trn_dl = DataLoader(trn_ds, 32, shuffle=True, collate_fn=trn_ds.collate_fn)
val_dl = DataLoader(val_ds, 32, shuffle=False, collate_fn=val_ds.collate_fn)
# Out:
# [08/27/25 02:31:10] INFO     1291                                                                                                      ]8;id=383448;file:///tmp/ipython-input-385011555.py:7\ipython-input-385011555.py]8;;\:]8;id=889309;file:///tmp/ipython-input-385011555.py:7#__init__:7\__init__:7]8;;\
#                     INFO     323                                                                                                       ]8;id=707037;file:///tmp/ipython-input-385011555.py:7\ipython-input-385011555.py]8;;\:]8;id=519320;file:///tmp/ipython-input-385011555.py:7#__init__:7\__init__:7]8;;\

# %%
import matplotlib.pyplot as plt

plt.imshow(trn_ds[-3][0])
plt.title(trn_ds[-3][1])
# Out:
# Text(0.5, 1.0, 'Parasitized')

# %%
def convBlock(ni, no):
    return nn.Sequential(
        nn.Dropout(0.2),
        nn.Conv2d(ni, no, kernel_size=3, padding=1),
        nn.ReLU(inplace=True),
        nn.BatchNorm2d(no),
        nn.MaxPool2d(2),
    )

class MalariaClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            convBlock(3, 64),
            convBlock(64, 64),
            convBlock(64, 128),
            convBlock(128, 256),
            convBlock(256, 512),
            convBlock(512, 64),
            nn.Flatten(),
            nn.Linear(256, 256),
            nn.Dropout(0.2),
            nn.ReLU(inplace=True),
            nn.Linear(256, len(id2int))
        )
        self.loss_fn = nn.CrossEntropyLoss()

    def forward(self, x):
        return self.model(x)

    def compute_metrics(self, preds, targets):
        loss = self.loss_fn(preds, targets)
        acc = (torch.max(preds, 1)[1] == targets).float().mean()
        return loss, acc

# %%
def train_batch(model, data, optimizer, criterion):
    model.train()
    ims, labels, _ = data
    _preds = model(ims)
    optimizer.zero_grad()
    loss, acc = criterion(_preds, labels)
    loss.backward()
    optimizer.step()
    return loss.item(), acc.item()

@torch.no_grad()
def validate_batch(model, data, criterion):
    model.eval()
    ims, labels, _ = data
    _preds = model(ims)
    loss, acc = criterion(_preds, labels)
    return loss.item(), acc.item()

# %%
from torch import optim
from torch_snippets.torch_loader import Report
model = MalariaClassifier().to(device)
criterion = model.compute_metrics
optimizer = optim.Adam(model.parameters(), lr=1e-3)
n_epochs = 2

log = Report(n_epochs)
for ex in range(n_epochs):
    N = len(trn_dl)
    for bx, data in enumerate(trn_dl):
        loss, acc = train_batch(model, data, optimizer, criterion)
        log.record(ex+(bx+1)/N, trn_loss=loss, trn_acc=acc, end='\r')

    N = len(val_dl)
    for bx, data in enumerate(val_dl):
        loss, acc = validate_batch(model, data, criterion)
        log.record(ex+(bx+1)/N, val_loss=loss, val_acc=acc, end='\r')

    log.report_avgs(ex+1)
# Out:
# EPOCH: 0.049  trn_loss: 0.059  trn_acc: 1.000  (9.37s - 374.83s remaining)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3785377589.py in <cell line: 0>()
#      10     N = len(trn_dl)
#      11     for bx, data in enumerate(trn_dl):
# ---> 12         loss, acc = train_batch(model, data, optimizer, criterion)
#      13         log.record(ex+(bx+1)/N, trn_loss=loss, trn_acc=acc, end='\r')
#      14
#
# /tmp/ipython-input-1522506847.py in train_batch(model, data, optimizer, criterion)
#       5     optimizer.zero_grad()
#       6     loss, acc = criterion(_preds, labels)
# ----> 7     loss.backward()
#       8     optimizer.step()
#       9     return loss.item(), acc.item()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     645                 inputs=inputs,
#     646             )
# --> 647         torch.autograd.backward(
#     648             self, gradient, retain_graph, create_graph, inputs=inputs
#     649         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     827         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828     try:
# --> 829         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830             t_outputs, *args, **kwargs
#     831         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
im2fmap = nn.Sequential(*(list(model.model[:5].children()) + list(model.model[5][:2].children())))

# %%
def im2gradCAM(x):
    model.eval()
    logits = model(x)
    heatmaps = []
    activations = im2fmap(x)
    print(activations.shape)
    pred = logits.max(-1)[-1]
    # get the model's prediction
    model.zero_grad()
    # compute gradients with respect to model's most confident logit
    logits[0,pred].backward(retain_graph=True)
    # get the gradients at the required featuremap location
    # and take the avg gradient for every featuremap
    pooled_grads = model.model[-6][1].weight.grad.data.mean((1,2,3))
    # multiply each activation map with corresponding gradient average
    for i in range(activations.shape[1]):
        activations[:,i,:,:] *= pooled_grads[i]
    # take the mean of all weighted activation maps
    # (that has been weighted by avg. grad at each fmap)
    heatmap = torch.mean(activations, dim=1)[0].cpu().detach()
    return heatmap, 'Uninfected' if pred.item() else 'Parasitized'

# %%
SZ = 128
def upsampleHeatmap(map, img):
    m,M = map.min(), map.max()
    map = 255 * ((map-m) / (M-m))
    map = np.uint8(map)
    map = cv2.resize(map, (SZ,SZ))
    map = cv2.applyColorMap(255-map, cv2.COLORMAP_JET)
    map = np.uint8(map)
    map = np.uint8(map*0.7 + img*0.3)
    return map

# %%
N = 20
_val_dl = DataLoader(val_ds, batch_size=N, shuffle=True, collate_fn=val_ds.collate_fn)
x,y,z = next(iter(_val_dl))

for i in range(N):
    image = resize(z[i], SZ)
    heatmap, pred = im2gradCAM(x[i:i+1])
    if(pred=='Uninfected'):
        continue
    heatmap = upsampleHeatmap(heatmap, image)
    subplots([image, heatmap], nc=2, figsize=(5,3), suptitle=pred)
